# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
speed_prms = pd.read_csv('exponential_speed_prms.csv')

# %%
np.abs(speed_prms['mean_z']-speed_prms['t0']).describe()
# Out:
# count    26.000000
# mean      0.033566
# std       0.028651
# min       0.000558
# 25%       0.009965
# 50%       0.023551
# 75%       0.061081
# max       0.105395
# dtype: float64

# %%
np.abs(speed_prms['mean_z']-speed_prms['t0'])
# Out:
# 0     0.020423
# 1     0.059929
# 2     0.009867
# 3     0.000558
# 4     0.006536
# 5     0.014656
# 6     0.003275
# 7     0.014505
# 8     0.070277
# 9     0.067170
# 10    0.061465
# 11    0.004591
# 12    0.021958
# 13    0.025144
# 14    0.046039
# 15    0.010262
# 16    0.068702
# 17    0.069378
# 18    0.026518
# 19    0.027522
# 20    0.105395
# 21    0.039184
# 22    0.067148
# 23    0.006738
# 24    0.004825
# 25    0.020649
# dtype: float64

# %%
plt.figure(figsize=(8, 3))
plt.boxplot(np.abs(speed_prms['mean_z']-speed_prms['t0']), 0, 'rs', 0);
plt.xlabel(r'$|mean_{z} - t_0|$', fontsize=20);
plt.yticks([1], [''])
# Out:
# ([<matplotlib.axis.YTick at 0x15694d5d0>], [Text(0, 1, '')])
